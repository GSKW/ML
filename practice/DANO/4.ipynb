# %%
import pandas as pd

# %%
data = pd.read_csv('task4_data.csv')

# %%
data
# Out:
#       column1   column2  column3   column4   column5   column6
# 0    0.476649 -0.979874        0 -0.107043 -0.809923  4.232886
# 1    1.122898  1.403421        0 -0.071643 -0.700846  4.321891
# 2    0.614606  1.345880        0 -0.133075  0.137968  5.126798
# 3   -0.807762 -0.795135        1  0.104951  0.777860  4.772678
# 4   -0.033675 -0.716721        1  0.015616  0.442111  4.545679
# ..        ...       ...      ...       ...       ...       ...
# 405  0.264000  0.599586        1 -0.086411  0.256329  4.379066
# 406  0.348495  0.736653        0 -1.465433  0.854784  5.968985
# 407  0.607171  0.811289        0 -1.205142  0.783252  5.742209
# 408 -0.000131  1.176686        1 -0.413386  1.522516  5.335160
# 409 -0.467549 -0.807206        1 -0.010717  0.298937  4.471814
#
# [410 rows x 6 columns]

# %%
data.corr()
# Out:
#           column1   column2   column3   column4   column5   column6
# column1  1.000000  0.045357 -0.731257 -0.055028 -0.429564 -0.015306
# column2  0.045357  1.000000 -0.036143 -0.011952 -0.036594 -0.021727
# column3 -0.731257 -0.036143  1.000000  0.086126  0.562413 -0.011164
# column4 -0.055028 -0.011952  0.086126  1.000000 -0.663889 -0.874603
# column5 -0.429564 -0.036594  0.562413 -0.663889  1.000000  0.809900
# column6 -0.015306 -0.021727 -0.011164 -0.874603  0.809900  1.000000

# %%
data.hist(bins=20, figsize=(20, 15))
# Out:
# array([[<AxesSubplot: title={'center': 'column1'}>,
#         <AxesSubplot: title={'center': 'column2'}>],
#        [<AxesSubplot: title={'center': 'column3'}>,
#         <AxesSubplot: title={'center': 'column4'}>],
#        [<AxesSubplot: title={'center': 'column5'}>,
#         <AxesSubplot: title={'center': 'column6'}>]], dtype=object)

# %%
import matplotlib.pyplot as plt

# %%
def plot_columns(col1, col2, size, figsize):
    plt.figure(figsize=figsize)
    plt.scatter(col1, col2, s=size)

# %%
plot_columns(data.column1, data.column2, 100, (10, 10))

# %%
import seaborn as sns
sns.set(style="ticks")
sns.pairplot(data)

# %% [markdown]
# ## Зависимые
# ### 4-5
# ### 4-6
# ### 5-6
# #### 1-6
# #### 6-2

# %%
import seaborn as sns
sns.set(style="ticks")
sns.pairplot(data, hue='column3')

# %% [markdown]
# ### 5-3
# ### 1-3
# ### 6-3 ??
#
#
#
# ## Зависимые
# ### 4 <-> 5
# ### 4 <-> 6
# ### 5 <-> 6
# #### 1-6
# #### 6-2

# %%
3
# Out:
# 3

# %%
data.column3
# Out:
# 0      0
# 1      0
# 2      0
# 3      1
# 4      1
#       ..
# 405    1
# 406    0
# 407    0
# 408    1
# 409    1
# Name: column3, Length: 410, dtype: int64

# %%
data.column5
# Out:
# 0     -0.809923
# 1     -0.700846
# 2      0.137968
# 3      0.777860
# 4      0.442111
#          ...
# 405    0.256329
# 406    0.854784
# 407    0.783252
# 408    1.522516
# 409    0.298937
# Name: column5, Length: 410, dtype: float64
